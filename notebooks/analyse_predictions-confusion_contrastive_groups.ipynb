# %% [markdown]
# ### Annotation file paths

# %%
config_file_path = "../configs/config_model1.json"
contrastive_grp_file = "../assets/contrastive_groups_list.txt"

# %%
import os
import sys
import pickle
import numpy as np
from pprint import pprint

sys.path.insert(0, "../")

from utils import load_json_config

# %%
# Load config file
config = load_json_config(config_file_path)

# %% [markdown]
# ### Get predictions

# %%
prediction_file_pickle_path = os.path.join('../', config['output_dir'], config['model_name'], 'test_results.pkl')

# %%
## some weird hacky stuff
with open(prediction_file_pickle_path, 'rb') as fp:
    try:
        logits_matrix, features_mat, targets_list, item_id_list, class_to_idx = pickle.load(fp)
    except ValueError as e:
        if str(e) != "not enough values to unpack (expected 5, got 4)":
            raise
        else:
            with open(prediction_file_pickle_path, 'rb') as fp:
                logits_matrix, targets_list, item_id_list, class_to_idx = pickle.load(fp)

# %%
logits_matrix.shape
# Out:
# (24777, 174)

# %%
targets_list.shape
# Out:
# (24777,)

# %% [markdown]
# ### Fetch mapping

# %%
label_to_action_grp_dict = {}
action_grp_to_label_dict = {}
action_grp_to_target_dict = {}
merge_grp_dict = {}

grp_id = 0
flag = 0

with open(contrastive_grp_file, "r", encoding='utf-8') as fp:
    for row in fp:
        if row.startswith('# '):
#             import pdb; pdb.set_trace()
            if row[2].isdigit():
                mapping = []
                for c in row[2:].strip():
                    if c.isdigit():
                        mapping.append(int(c))
                merge_grp_dict[grp_id] = mapping
            continue
        elif not row.strip():
            if flag == 0:
                flag = 1
                continue
            else:
                flag = 0
                grp_id += 1
        elif row.startswith('##'):
            break
        else:
            label = row.strip().strip(",").strip("\"").strip("'")
            label_to_action_grp_dict[class_to_idx[label]] = grp_id
            if grp_id not in action_grp_to_label_dict:
                action_grp_to_label_dict[grp_id] = [label]
                action_grp_to_target_dict[grp_id] = [class_to_idx[label]]                
            else:                
                action_grp_to_label_dict[grp_id].append(label)
                action_grp_to_target_dict[grp_id].append(class_to_idx[label])

# %%
merge_grp_dict
# Out:
# {24: [0, 0, 1, 1], 40: [0, 0, 1, 2], 67: [0, 0, 1]}

# %%
for key, value in action_grp_to_target_dict.items():
    print(key, value)
    break
# Out:
# 0 [173, 63]

# %%
def get_argmax_over_predefined_targets(targets, logits):
    return logits[targets].argmax()

# %% [markdown]
# ### Generate results for action groups separately (confusion mat, avg precision etc.)

# %%
# action_grp_preds_and_true = {}
# for logits, target in zip(logits_matrix, targets_list):
    
#     ## if label is not present in action groups generated
#     if target not in label_to_action_grp_dict:
#         continue
#     action_grp_belongingness = label_to_action_grp_dict[target]
#     targets_action_grp = action_grp_to_target_dict[action_grp_belongingness]
    
#     pred_ag_label = get_argmax_over_predefined_targets(targets_action_grp, logits)
#     true_ag_label = targets_action_grp.index(target)
    
#     if action_grp_belongingness not in action_grp_preds_and_true:
#         action_grp_preds_and_true[action_grp_belongingness] = {"y_pred": [pred_ag_label],
#                                                                "y_true": [true_ag_label]}
#     else:
#         action_grp_preds_and_true[action_grp_belongingness]["y_pred"].append(pred_ag_label)
#         action_grp_preds_and_true[action_grp_belongingness]["y_true"].append(true_ag_label)

# %%
action_grp_preds_and_true = []
for i in range(len(action_grp_to_target_dict)):
    true_ag_label = []
    pred_ag_label = []
    
    targets_action_grp = action_grp_to_target_dict[i]
    for logits, target in zip(logits_matrix, targets_list):
        if target not in targets_action_grp:
            continue
        else:
            true_ag_label.append(targets_action_grp.index(target))
            pred_ag_label.append(get_argmax_over_predefined_targets(targets_action_grp, logits))
    
    action_grp_preds_and_true.append({'y_true': true_ag_label, 'y_pred': pred_ag_label})

# %%
def merge_classes(data, target_names, mapping_list):
    mapping = {key: val for key, val in enumerate(mapping_list)}
    
    y_pred_new = []
    for val in data['y_pred']:
        y_pred_new.append(mapping[val])
    
    y_true_new = []
    for val in data['y_true']:
        y_true_new.append(mapping[val])
    
    data['y_pred'] = y_pred_new
    data['y_true'] = y_true_new
    
    target_list_done = []
    target_names_new = []
    for i, elem in enumerate(mapping_list):
        if elem not in target_list_done:
            target_names_new.append(target_names[i])
            target_list_done.append(elem)

    return data, target_names_new

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from pprint import pprint

# %%
action_grp_ap_average = 0
action_grp_ap_most_probable_average = 0

for action_grp, data in enumerate(action_grp_preds_and_true):
    
    target_names = []
    for ind in action_grp_to_target_dict[action_grp]:
        target_names.append(class_to_idx[ind])
    
    ## pre-process potential class clubbing
    if action_grp in merge_grp_dict:
        data, target_names = merge_classes(data, target_names, merge_grp_dict[action_grp])
    

    confusion_mat = confusion_matrix(data['y_true'], data['y_pred'])
    report = classification_report(data['y_true'], data['y_pred'], target_names=target_names)

    
    
    """
    Calculate metrics for each label, and find their average, weighted by support 
    (the number of true instances for each label). This alters ‘macro’ to account 
    for label imbalance; it can result in an F-score that is not between precision and recall.
    """
    
    precision_recall_fscore_support_val = precision_recall_fscore_support(
                                                    data['y_true'],
                                                    data['y_pred'],
                                                    average='weighted'
                                                    )
    accuracy_group = accuracy_score(data['y_true'], data['y_pred'])
    
    print("#" * 80)
    print("{}: ACTION GROUP".format(action_grp + 1))
    print("\nConfusion Matrix:")
    print(confusion_mat)
    
    for i, name in enumerate(target_names):
        print("{} --> {}".format(i, name))
    
#     print(report)
    ap_most_probable = np.max(np.sum(confusion_mat, axis=1)) / np.sum(confusion_mat)
    print("Average precision = {:.2f}% ({:.2f}%)\n".format(
#                         precision_recall_fscore_support_val[0] * 100,
                        accuracy_group * 100,
                        ap_most_probable * 100))
#     action_grp_ap_average += precision_recall_fscore_support_val[0]
    action_grp_ap_average += accuracy_group
    action_grp_ap_most_probable_average += ap_most_probable
    
action_grp_ap_average /= len(action_grp_preds_and_true)
action_grp_ap_most_probable_average /= len(action_grp_preds_and_true)
# Out:
# ################################################################################
# 1: ACTION GROUP
#
# Confusion Matrix:
# [[119  18]
#  [ 60  47]]
# 0 --> Wiping something off of something
# 1 --> Pretending or failing to wipe something off of something
# Average precision = 68.03% (56.15%)
#
# ################################################################################
# 2: ACTION GROUP
#
# Confusion Matrix:
# [[193  35]
#  [ 49  57]]
# 0 --> Closing something
# 1 --> Pretending to close something without actually closing it
# Average precision = 74.85% (68.26%)
#
# ################################################################################
# 3: ACTION GROUP
#
# Confusion Matrix:
# [[256  76]
#  [ 37 164]]
# 0 --> Opening something
# 1 --> Pretending to open something without actually opening it
# Average precision = 78.80% (62.29%)
#
# ################################################################################
# 4: ACTION GROUP
#
# Confusion Matrix:
# [[159  40]
#  [  7 221]]
# 0 --> Picking something up
# 1 --> Pretending to pick something up
# Average precision = 88.99% (53.40%)
#
# ################################################################################
# 5: ACTION GROUP
#
# Confusion Matrix:
# [[366  25]
#  [ 20  55]]
# 0 --> Turning something upside down
# 1 --> Pretending to turn something upside down
# Average precision = 90.34% (83.91%)
#
# ################################################################################
# 6: ACTION GROUP
#
# Confusion Matrix:
# [[275  17]
#  [ 21  47]]
# 0 --> Putting something into something
# 1 --> Pretending to put something into something
# Average precision = 89.44% (81.11%)
#
# ################################################################################
# 7: ACTION GROUP
#
# Confusion Matrix:
# [[114  13]
#  [ 10  13]]
# 0 --> Putting something behind something
# 1 --> Pretending to put something behind something
# Average precision = 84.67% (84.67%)
#
# ################################################################################
# 8: ACTION GROUP
#
# Confusion Matrix:
# [[192  11]
#  [ 10  29]]
# 0 --> Putting something next to something
# 1 --> Pretending to put something next to something
# Average precision = 91.32% (83.88%)
#
# ################################################################################
# 9: ACTION GROUP
#
# Confusion Matrix:
# [[292   8]
#  [ 11  95]]
# 0 --> Putting something on a surface
# 1 --> Pretending to put something on a surface
# Average precision = 95.32% (73.89%)
#
# ################################################################################
# 10: ACTION GROUP
#
# Confusion Matrix:
# [[136   3]
#  [ 10  28]]
# 0 --> Putting something onto something
# 1 --> Pretending to put something onto something
# Average precision = 92.66% (78.53%)
#
# ################################################################################
# 11: ACTION GROUP
#
# Confusion Matrix:
# [[54  5]
#  [ 5 13]]
# 0 --> Putting something underneath something
# 1 --> Pretending to put something underneath something
# Average precision = 87.01% (76.62%)
#
# ################################################################################
# 12: ACTION GROUP
#
# Confusion Matrix:
# [[54 11]
#  [13 13]]
# 0 --> Scooping something up with something
# 1 --> Pretending to scoop something up with something
# Average precision = 73.63% (71.43%)
#
# ################################################################################
# 13: ACTION GROUP
#
# Confusion Matrix:
# [[169  15]
#  [ 12  35]]
# 0 --> Throwing something
# 1 --> Pretending to throw something
# Average precision = 88.31% (79.65%)
#
# ################################################################################
# 14: ACTION GROUP
#
# Confusion Matrix:
# [[174  65]
#  [ 11  36]]
# 0 --> Taking something out of something
# 1 --> Pretending to take something out of something
# Average precision = 73.43% (83.57%)
#
# ################################################################################
# 15: ACTION GROUP
#
# Confusion Matrix:
# [[59  5]
#  [13 14]]
# 0 --> Spreading something onto something
# 1 --> Pretending to spread air onto something
# Average precision = 80.22% (70.33%)
#
# ################################################################################
# 16: ACTION GROUP
#
# Confusion Matrix:
# [[53 11]
#  [11 47]]
# 0 --> Sprinkling something onto something
# 1 --> Pretending to sprinkle air onto something
# Average precision = 81.97% (52.46%)
#
# ################################################################################
# 17: ACTION GROUP
#
# Confusion Matrix:
# [[74  5]
#  [ 4 52]]
# 0 --> Pouring something out of something
# 1 --> Pretending to pour something out of something, but something is empty
# Average precision = 93.33% (58.52%)
#
# ################################################################################
# 18: ACTION GROUP
#
# Confusion Matrix:
# [[110  18]
#  [  6 119]]
# 0 --> Taking something from somewhere
# 1 --> Pretending to take something from somewhere
# Average precision = 90.51% (50.59%)
#
# ################################################################################
# 19: ACTION GROUP
#
# Confusion Matrix:
# [[ 60  15]
#  [  5 199]]
# 0 --> Twisting (wringing) something wet until water comes out
# 1 --> Twisting something
# Average precision = 92.83% (73.12%)
#
# ################################################################################
# 20: ACTION GROUP
#
# Confusion Matrix:
# [[471  59]
#  [ 37 331]]
# 0 --> Tearing something into two pieces
# 1 --> Tearing something just a little bit
# Average precision = 89.31% (59.02%)
#
# ################################################################################
# 21: ACTION GROUP
#
# Confusion Matrix:
# [[292  40]
#  [ 21 207]]
# 0 --> Opening something
# 1 --> Closing something
# Average precision = 89.11% (59.29%)
#
# ################################################################################
# 22: ACTION GROUP
#
# Confusion Matrix:
# [[33  2]
#  [ 1 23]]
# 0 --> Poking a stack of something so the stack collapses
# 1 --> Poking a stack of something without the stack collapsing
# Average precision = 94.92% (59.32%)
#
# ################################################################################
# 23: ACTION GROUP
#
# Confusion Matrix:
# [[141  11]
#  [ 17  59]]
# 0 --> Attaching something to something
# 1 --> Trying but failing to attach something to something because it doesn't stick
# Average precision = 87.72% (66.67%)
#
# ################################################################################
# 24: ACTION GROUP
#
# Confusion Matrix:
# [[263  22]
#  [ 40 175]]
# 0 --> Folding something
# 1 --> Unfolding something
# Average precision = 87.60% (57.00%)
#
# ################################################################################
# 25: ACTION GROUP
#
# Confusion Matrix:
# [[343  13]
#  [ 11 249]]
# 0 --> Moving something across a surface until it falls down
# 1 --> Moving something across a surface without it falling down
# Average precision = 96.10% (57.79%)
#
# ################################################################################
# 26: ACTION GROUP
#
# Confusion Matrix:
# [[407  10]
#  [ 12 300]]
# 0 --> Covering something with something
# 1 --> Uncovering something
# Average precision = 96.98% (57.20%)
#
# ################################################################################
# 27: ACTION GROUP
#
# Confusion Matrix:
# [[101   8]
#  [ 14 113]]
# 0 --> Throwing something in the air and catching it
# 1 --> Throwing something in the air and letting it fall
# Average precision = 90.68% (53.81%)
#
# ################################################################################
# 28: ACTION GROUP
#
# Confusion Matrix:
# [[ 72   2]
#  [  2 109]]
# 0 --> Lifting up one end of something without letting it drop down
# 1 --> Lifting up one end of something, then letting it drop down
# Average precision = 97.84% (60.00%)
#
# ################################################################################
# 29: ACTION GROUP
#
# Confusion Matrix:
# [[101   0]
#  [  1 109]]
# 0 --> Lifting something up completely without letting it drop down
# 1 --> Lifting something up completely, then letting it drop down
# Average precision = 99.53% (52.13%)
#
# ################################################################################
# 30: ACTION GROUP
#
# Confusion Matrix:
# [[18  1]
#  [ 3 37]]
# 0 --> Lifting a surface with something on it but not enough for it to slide down
# 1 --> Lifting a surface with something on it until it starts sliding down
# Average precision = 93.22% (67.80%)
#
# ################################################################################
# 31: ACTION GROUP
#
# Confusion Matrix:
# [[60  0]
#  [10 47]]
# 0 --> Pulling two ends of something so that it gets stretched
# 1 --> Pulling two ends of something so that it separates into two pieces
# Average precision = 91.45% (51.28%)
#
# ################################################################################
# 32: ACTION GROUP
#
# Confusion Matrix:
# [[49  5]
#  [ 3 31]]
# 0 --> Moving something and something so they collide with each other
# 1 --> Moving something and something so they pass each other
# Average precision = 90.91% (61.36%)
#
# ################################################################################
# 33: ACTION GROUP
#
# Confusion Matrix:
# [[316  52]
#  [ 67 259]]
# 0 --> Something falling like a feather or paper
# 1 --> Something falling like a rock
# Average precision = 82.85% (53.03%)
#
# ################################################################################
# 34: ACTION GROUP
#
# Confusion Matrix:
# [[185  24]
#  [ 25 233]]
# 0 --> Spinning something so it continues spinning
# 1 --> Spinning something that quickly stops spinning
# Average precision = 89.51% (55.25%)
#
# ################################################################################
# 35: ACTION GROUP
#
# Confusion Matrix:
# [[39  7]
#  [ 1 53]]
# 0 --> Putting something that can't roll onto a slanted surface, so it slides down
# 1 --> Putting something that can't roll onto a slanted surface, so it stays where it is
# Average precision = 92.00% (54.00%)
#
# ################################################################################
# 36: ACTION GROUP
#
# Confusion Matrix:
# [[73 14]
#  [10 47]]
# 0 --> Something colliding with something and both are being deflected
# 1 --> Something colliding with something and both come to a halt
# Average precision = 83.33% (60.42%)
#
# ################################################################################
# 37: ACTION GROUP
#
# Confusion Matrix:
# [[435  30]
#  [ 82 155]]
# 0 --> Plugging something into something
# 1 --> Plugging something into something but pulling it right out as you remove your hand
# Average precision = 84.05% (66.24%)
#
# ################################################################################
# 38: ACTION GROUP
#
# Confusion Matrix:
# [[124   6]
#  [  8 176]]
# 0 --> Tilting something with something on it slightly so it doesn't fall down
# 1 --> Tilting something with something on it until it falls off
# Average precision = 95.54% (58.60%)
#
# ################################################################################
# 39: ACTION GROUP
#
# Confusion Matrix:
# [[31  8]
#  [ 4 29]]
# 0 --> Burying something in something
# 1 --> Digging something out of something
# Average precision = 83.33% (54.17%)
#
# ################################################################################
# 40: ACTION GROUP
#
# Confusion Matrix:
# [[ 1 14]
#  [ 1 31]]
# 0 --> Poking a hole into some substance
# 1 --> Poking a hole into something soft
# Average precision = 68.09% (68.09%)
#
# ################################################################################
# 41: ACTION GROUP
#
# Confusion Matrix:
# [[290   5   1]
#  [ 10  95   1]
#  [  5   3   9]]
# 0 --> Poking something so it slightly moves
# 1 --> Poking something so that it falls over
# 2 --> Poking something so that it spins around
# Average precision = 94.03% (70.64%)
#
# ################################################################################
# 42: ACTION GROUP
#
# Confusion Matrix:
# [[276   2]
#  [ 27  13]]
# 0 --> Pouring something into something
# 1 --> Trying to pour something into something, but missing so it spills next to it
# Average precision = 90.88% (87.42%)
#
# ################################################################################
# 43: ACTION GROUP
#
# Confusion Matrix:
# [[262   8   8]
#  [ 19  30   1]
#  [ 32   7  12]]
# 0 --> Pouring something into something
# 1 --> Pouring something into something until it overflows
# 2 --> Pouring something onto something
# Average precision = 80.21% (73.35%)
#
# ################################################################################
# 44: ACTION GROUP
#
# Confusion Matrix:
# [[ 38   1]
#  [ 10 407]]
# 0 --> Burying something in something
# 1 --> Covering something with something
# Average precision = 97.59% (91.45%)
#
# ################################################################################
# 45: ACTION GROUP
#
# Confusion Matrix:
# [[410   7]
#  [  0  33]]
# 0 --> Covering something with something
# 1 --> Digging something out of something
# Average precision = 98.44% (92.67%)
#
# ################################################################################
# 46: ACTION GROUP
#
# Confusion Matrix:
# [[131  22]
#  [ 30  73]]
# 0 --> Bending something so that it deforms
# 1 --> Bending something until it breaks
# Average precision = 79.69% (59.77%)
#
# ################################################################################
# 47: ACTION GROUP
#
# Confusion Matrix:
# [[116  11]
#  [ 10 141]]
# 0 --> Dropping something behind something
# 1 --> Dropping something in front of something
# Average precision = 92.45% (54.32%)
#
# ################################################################################
# 48: ACTION GROUP
#
# Confusion Matrix:
# [[137  41]
#  [ 40 194]]
# 0 --> Dropping something into something
# 1 --> Dropping something onto something
# Average precision = 80.34% (56.80%)
#
# ################################################################################
# 49: ACTION GROUP
#
# Confusion Matrix:
# [[117  10]
#  [  3 124]]
# 0 --> Dropping something behind something
# 1 --> Putting something behind something
# Average precision = 94.88% (50.00%)
#
# ################################################################################
# 50: ACTION GROUP
#
# Confusion Matrix:
# [[147   4]
#  [  6 129]]
# 0 --> Dropping something in front of something
# 1 --> Putting something in front of something
# Average precision = 96.50% (52.80%)
#
# ################################################################################
# 51: ACTION GROUP
#
# Confusion Matrix:
# [[159  19]
#  [ 19 273]]
# 0 --> Dropping something into something
# 1 --> Putting something into something
# Average precision = 91.91% (62.13%)
#
# ################################################################################
# 52: ACTION GROUP
#
# Confusion Matrix:
# [[125  12]
#  [  7 196]]
# 0 --> Dropping something next to something
# 1 --> Putting something next to something
# Average precision = 94.41% (59.71%)
#
# ################################################################################
# 53: ACTION GROUP
#
# Confusion Matrix:
# [[225   9]
#  [  5 134]]
# 0 --> Dropping something onto something
# 1 --> Putting something onto something
# Average precision = 96.25% (62.73%)
#
# ################################################################################
# 54: ACTION GROUP
#
# Confusion Matrix:
# [[187  12]
#  [  6 294]]
# 0 --> Picking something up
# 1 --> Putting something on a surface
# Average precision = 96.39% (60.12%)
#
# ################################################################################
# 55: ACTION GROUP
#
# Confusion Matrix:
# [[ 28  12]
#  [ 12 280]]
# 0 --> Failing to put something into something because something does not fit
# 1 --> Putting something into something
# Average precision = 92.77% (87.95%)
#
# ################################################################################
# 56: ACTION GROUP
#
# Confusion Matrix:
# [[ 56   9]
#  [ 11 188]]
# 0 --> Scooping something up with something
# 1 --> Picking something up
# Average precision = 92.42% (75.38%)
# ################################################################################
# 57: ACTION GROUP
#
# Confusion Matrix:
# [[209   9]
#  [  3 106]]
# 0 --> Tipping something over
# 1 --> Touching (without moving) part of something
# Average precision = 96.33% (66.67%)
#
# ################################################################################
# 58: ACTION GROUP
#
# Confusion Matrix:
# [[203  15]
#  [ 27  28]]
# 0 --> Tipping something over
# 1 --> Tipping something with something in it over, so something in it falls out
# Average precision = 84.62% (79.85%)
#
# ################################################################################
# 59: ACTION GROUP
#
# Confusion Matrix:
# [[ 55   0]
#  [  1 108]]
# 0 --> Tipping something with something in it over, so something in it falls out
# 1 --> Touching (without moving) part of something
# Average precision = 99.39% (66.46%)
#
# ################################################################################
# 60: ACTION GROUP
#
# Confusion Matrix:
# [[ 96   0   4  11   5  11]
#  [  3  96   5  12  11   8]
#  [  3   2  37   4   4   9]
#  [  5   2   6 172  10   8]
#  [ 16   8   2  15  80  18]
#  [ 14   2  10  10  23 233]]
# 0 --> Putting something behind something
# 1 --> Putting something in front of something
# 2 --> Putting something underneath something
# 3 --> Putting something next to something
# 4 --> Putting something onto something
# 5 --> Putting something into something
# Average precision = 74.76% (30.58%)
#
# ################################################################################
# 61: ACTION GROUP
#
# Confusion Matrix:
# [[274  14]
#  [ 18 342]]
# 0 --> Putting something similar to other things that are already on the table
# 1 --> Taking one of many similar things on the table
# Average precision = 95.06% (55.56%)
#
# ################################################################################
# 62: ACTION GROUP
#
# Confusion Matrix:
# [[285   7]
#  [ 24 215]]
# 0 --> Putting something into something
# 1 --> Taking something out of something
# Average precision = 94.16% (54.99%)
#
# ################################################################################
# 63: ACTION GROUP
#
# Confusion Matrix:
# [[288  12]
#  [  7  64]]
# 0 --> Putting something on a surface
# 1 --> Putting something on the edge of something so it is not supported and falls down
# Average precision = 94.88% (80.86%)
#
# ################################################################################
# 64: ACTION GROUP
#
# Confusion Matrix:
# [[ 97   3  14]
#  [  5 118   3]
#  [ 15   3  83]]
# 0 --> Laying something on the table on its side, not upright
# 1 --> Putting something that cannot actually stand upright upright on the table, so it falls on its side
# 2 --> Putting something upright on the table
# Average precision = 87.39% (36.95%)
#
# ################################################################################
# 65: ACTION GROUP
#
# Confusion Matrix:
# [[15  1  2  4  1]
#  [ 0 30  2  3  4]
#  [ 0  1 15  1  1]
#  [11  2  2 50  3]
#  [ 3  4  3 10 18]]
# 0 --> Pretending to put something behind something
# 1 --> Pretending to put something next to something
# 2 --> Pretending to put something underneath something
# 3 --> Pretending to put something into something
# 4 --> Pretending to put something onto something
# Average precision = 68.82% (36.56%)
#
# ################################################################################
# 66: ACTION GROUP
#
# Confusion Matrix:
# [[ 70   4]
#  [  3 200]]
# 0 --> Putting something on a flat surface without letting it roll
# 1 --> Rolling something on a flat surface
# Average precision = 97.47% (73.29%)
#
# ################################################################################
# 67: ACTION GROUP
#
# Confusion Matrix:
# [[ 8  1  8]
#  [ 0 44 16]
#  [ 4 12 93]]
# 0 --> Spilling something behind something
# 1 --> Spilling something next to something
# 2 --> Spilling something onto something
# Average precision = 77.96% (58.60%)
#
# ################################################################################
# 68: ACTION GROUP
#
# Confusion Matrix:
# [[370   5]
#  [  5  69]]
# 0 --> Letting something roll along a flat surface
# 1 --> Putting something on a flat surface without letting it roll
# Average precision = 97.77% (83.52%)
#
# ################################################################################
# 69: ACTION GROUP
#
# Confusion Matrix:
# [[15  3]
#  [ 3 91]]
# 0 --> Putting something onto a slanted surface but it doesn't glide down
# 1 --> Letting something roll down a slanted surface
# Average precision = 94.64% (83.93%)

# %%
print("Average precision among all action groups = {:.2f}%".format(action_grp_ap_average * 100))
print("Average precision (most probable class) among all action groups= {:.2f}%".format(action_grp_ap_most_probable_average * 100))
# Out:
# Average precision among all action groups = 88.87%
# Average precision (most probable class) among all action groups= 64.93%
